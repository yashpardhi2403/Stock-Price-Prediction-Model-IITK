# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# Load the data
df = pd.read_csv('G.csv')
data = df.reset_index()['Close']

# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
data1 = scaler.fit_transform(np.array(data).reshape(-1, 1))
data = []

for i in data1:
    if ((np.isnan(i)) != True):
        data.append(i)
data=np.array(data).reshape(-1,1)
# data = np.array(data).reshape(-1,1)
# print((data))
# Split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data = data[:train_size, :]
test_data = data[train_size:, :]

print(data)
print(train_data)

# c = 0

# print(c)
#     else:
#         print("no")
#     print(type(i))
# Out:
# [[0.03012963]
#  [0.03008561]
#  [0.02971147]
#  ...
#  [0.98833552]
#  [0.98382381]
#  [0.99647869]]
# [[0.03012963]
#  [0.03008561]
#  [0.02971147]
#  ...
#  [0.54425911]
#  [0.55427295]
#  [0.55735413]]

# %%
# Prepare the data for training
def prepare_data(data, look_back=1):
    X, Y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back)])
        Y.append(data[i+look_back])
    return np.array(X), np.array(Y)

look_back = 100
train_X, train_Y = prepare_data(train_data, look_back)
test_X, test_Y = prepare_data(test_data, look_back)

train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

# %%
# Build the LSTM model
# model = Sequential()
# model.add(LSTM(64,return_sequences=True, input_shape=(look_back, 1)))
# model.add(LSTM(32,return_sequences=True))
# model.add(LSTM(16))
# model.add(Dense(1))
from tensorflow.keras.models import load_model
model = load_model('combmodel.h5')
model.compile(loss='mean_squared_error', optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 64)           16896
#
#  lstm_1 (LSTM)               (None, 100, 32)           12416
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 32,465
# Trainable params: 32,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the modeldwqefqqqqqqq
model.fit(train_X, train_Y, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 15s 260ms/step - loss: 1.3214e-04
# Epoch 2/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.7608e-05
# Epoch 3/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.5915e-05
# Epoch 4/100
# 42/42 [==============================] - 11s 251ms/step - loss: 3.9509e-05
# Epoch 5/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.7684e-05
# Epoch 6/100
# 42/42 [==============================] - 10s 245ms/step - loss: 3.4669e-05
# Epoch 7/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.5842e-05
# Epoch 8/100
# 42/42 [==============================] - 10s 247ms/step - loss: 3.4649e-05
# Epoch 9/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.8192e-05
# Epoch 10/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.6802e-05
# Epoch 11/100
# 42/42 [==============================] - 10s 243ms/step - loss: 3.5983e-05
# Epoch 12/100
# 42/42 [==============================] - 10s 247ms/step - loss: 4.3556e-05
# Epoch 13/100
# 42/42 [==============================] - 10s 248ms/step - loss: 4.2470e-05
# Epoch 14/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.3573e-05
# Epoch 15/100
# 42/42 [==============================] - 10s 249ms/step - loss: 4.1592e-05
# Epoch 16/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.4991e-05
# Epoch 17/100
# 42/42 [==============================] - 10s 247ms/step - loss: 3.7210e-05
# Epoch 18/100
# 42/42 [==============================] - 11s 266ms/step - loss: 3.5295e-05
# Epoch 19/100
# 42/42 [==============================] - 11s 254ms/step - loss: 4.2856e-05
# Epoch 20/100
# 42/42 [==============================] - 10s 247ms/step - loss: 3.5269e-05
# Epoch 21/100
# 42/42 [==============================] - 11s 256ms/step - loss: 4.2417e-05
# Epoch 22/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.5094e-05
# Epoch 23/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.9052e-05
# Epoch 24/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.3381e-05
# Epoch 25/100
# 42/42 [==============================] - 11s 252ms/step - loss: 3.3876e-05
# Epoch 26/100
# 42/42 [==============================] - 10s 242ms/step - loss: 3.0934e-05
# Epoch 27/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.6771e-05
# Epoch 28/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.3164e-05
# Epoch 29/100
# 42/42 [==============================] - 10s 247ms/step - loss: 3.1125e-05
# Epoch 30/100
# 42/42 [==============================] - 10s 244ms/step - loss: 3.0974e-05
# Epoch 31/100
# 42/42 [==============================] - 10s 241ms/step - loss: 3.3066e-05
# Epoch 32/100
# 42/42 [==============================] - 10s 244ms/step - loss: 3.6948e-05
# Epoch 33/100
# 42/42 [==============================] - 10s 245ms/step - loss: 3.1456e-05
# Epoch 34/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.2423e-05
# Epoch 35/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.2294e-05
# Epoch 36/100
# 42/42 [==============================] - 11s 256ms/step - loss: 3.3853e-05
# Epoch 37/100
# 42/42 [==============================] - 10s 249ms/step - loss: 4.5551e-05
# Epoch 38/100
# 42/42 [==============================] - 11s 251ms/step - loss: 4.3436e-05
# Epoch 39/100
# 42/42 [==============================] - 10s 250ms/step - loss: 3.4980e-05
# Epoch 40/100
# 42/42 [==============================] - 11s 252ms/step - loss: 3.1073e-05
# Epoch 41/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.0245e-05
# Epoch 42/100
# 42/42 [==============================] - 10s 250ms/step - loss: 3.3908e-05
# Epoch 43/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.5267e-05
# Epoch 44/100
# 42/42 [==============================] - 10s 243ms/step - loss: 4.4650e-05
# Epoch 45/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.8383e-05
# Epoch 46/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.1262e-05
# Epoch 47/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.1859e-05
# Epoch 48/100
# 42/42 [==============================] - 10s 247ms/step - loss: 3.8298e-05
# Epoch 49/100
# 42/42 [==============================] - 10s 243ms/step - loss: 3.4109e-05
# Epoch 50/100
# 42/42 [==============================] - 10s 250ms/step - loss: 3.0329e-05
# Epoch 51/100
# 42/42 [==============================] - 10s 247ms/step - loss: 3.5791e-05
# Epoch 52/100
# 42/42 [==============================] - 10s 243ms/step - loss: 3.3696e-05
# Epoch 53/100
# 42/42 [==============================] - 11s 253ms/step - loss: 2.8456e-05
# Epoch 54/100
# 42/42 [==============================] - 10s 245ms/step - loss: 2.9336e-05
# Epoch 55/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.4871e-05
# Epoch 56/100
# 42/42 [==============================] - 11s 251ms/step - loss: 3.4289e-05
# Epoch 57/100
# 42/42 [==============================] - 11s 250ms/step - loss: 3.1353e-05
# Epoch 58/100
# 42/42 [==============================] - 10s 247ms/step - loss: 2.9591e-05
# Epoch 59/100
# 42/42 [==============================] - 11s 252ms/step - loss: 3.1368e-05
# Epoch 60/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.4600e-05
# Epoch 61/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.1455e-05
# Epoch 62/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.0313e-05
# Epoch 63/100
# 42/42 [==============================] - 10s 244ms/step - loss: 2.9030e-05
# Epoch 64/100
# 42/42 [==============================] - 10s 248ms/step - loss: 2.9394e-05
# Epoch 65/100
# 42/42 [==============================] - 10s 246ms/step - loss: 2.9449e-05
# Epoch 66/100
# 42/42 [==============================] - 11s 251ms/step - loss: 2.9592e-05
# Epoch 67/100
# 42/42 [==============================] - 11s 253ms/step - loss: 2.9313e-05
# Epoch 68/100
# 42/42 [==============================] - 10s 244ms/step - loss: 3.3430e-05
# Epoch 69/100
# 42/42 [==============================] - 10s 244ms/step - loss: 3.5581e-05
# Epoch 70/100
# 42/42 [==============================] - 10s 245ms/step - loss: 2.8779e-05
# Epoch 71/100
# 42/42 [==============================] - 10s 245ms/step - loss: 3.3389e-05
# Epoch 72/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.0477e-05
# Epoch 73/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.2970e-05
# Epoch 74/100
# 42/42 [==============================] - 10s 247ms/step - loss: 3.1125e-05
# Epoch 75/100
# 42/42 [==============================] - 11s 255ms/step - loss: 3.0126e-05
# Epoch 76/100
# 42/42 [==============================] - 10s 244ms/step - loss: 3.0378e-05
# Epoch 77/100
# 42/42 [==============================] - 10s 250ms/step - loss: 3.5206e-05
# Epoch 78/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.5611e-05
# Epoch 79/100
# 42/42 [==============================] - 11s 252ms/step - loss: 3.1232e-05
# Epoch 80/100
# 42/42 [==============================] - 11s 250ms/step - loss: 2.8872e-05
# Epoch 81/100
# 42/42 [==============================] - 11s 250ms/step - loss: 3.9218e-05
# Epoch 82/100
# 42/42 [==============================] - 11s 262ms/step - loss: 3.7037e-05
# Epoch 83/100
# 42/42 [==============================] - 12s 292ms/step - loss: 3.3094e-05
# Epoch 84/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.0828e-05
# Epoch 85/100
# 42/42 [==============================] - 11s 256ms/step - loss: 3.0348e-05
# Epoch 86/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.1446e-05
# Epoch 87/100
# 42/42 [==============================] - 11s 255ms/step - loss: 2.8320e-05
# Epoch 88/100
# 42/42 [==============================] - 11s 251ms/step - loss: 2.7158e-05
# Epoch 89/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.0035e-05
# Epoch 90/100
# 42/42 [==============================] - 11s 255ms/step - loss: 2.7996e-05
# Epoch 91/100
# 42/42 [==============================] - 10s 250ms/step - loss: 3.2259e-05
# Epoch 92/100
# 42/42 [==============================] - 10s 245ms/step - loss: 3.7478e-05
# Epoch 93/100
# 42/42 [==============================] - 10s 250ms/step - loss: 3.3470e-05
# Epoch 94/100
# 42/42 [==============================] - 11s 258ms/step - loss: 2.9532e-05
# Epoch 95/100
# 42/42 [==============================] - 10s 249ms/step - loss: 3.3184e-05
# Epoch 96/100
# 42/42 [==============================] - 10s 248ms/step - loss: 3.0094e-05
# Epoch 97/100
# 42/42 [==============================] - 10s 245ms/step - loss: 3.6839e-05
# Epoch 98/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.8494e-05
# Epoch 99/100
# 42/42 [==============================] - 10s 246ms/step - loss: 3.2446e-05
# Epoch 100/100
# 42/42 [==============================] - 10s 245ms/step - loss: 2.8924e-05

# %%
# Evaluate the model
train_score = model.evaluate(train_X, train_Y, verbose=0)
test_score = model.evaluate(test_X, test_Y, verbose=0)
print('Train Score: {:.2f} MSE ({:.2f} RMSE)'.format(train_score, np.sqrt(train_score)))
print('Test Score: {:.2f} MSE ({:.2f} RMSE)'.format(test_score, np.sqrt(test_score)))

# Make predictions
train_predict = model.predict(train_X)
test_predict = model.predict(test_X)
# scaler.scale_
# Inverse the scaling
scale_factor = 1/scaler.scale_
train_predict = scaler.inverse_transform(train_predict)
# train_predict1=train_predict1*scale_factor
train_Y = scaler.inverse_transform(train_Y)
# train_Y=train_Y*scale_factor
test_predict = scaler.inverse_transform(test_predict)
# test_predict1 = test_predict1*scale_factor
test_Y = scaler.inverse_transform(test_Y)
# test_Y = test_Y*scale_factor

print(train_predict)
print(train_Y)
# Out:
# Train Score: 0.00 MSE (0.01 RMSE)
# Test Score: 0.00 MSE (0.02 RMSE)
# 84/84 [==============================] - 5s 46ms/step
# 19/19 [==============================] - 1s 51ms/step
# [[ 50.40673]
#  [ 50.33074]
#  [ 50.06138]
#  ...
#  [500.50568]
#  [502.7038 ]
#  [512.4131 ]]
# [[ 48.875   ]
#  [ 48.474998]
#  [ 47.790001]
#  ...
#  [505.200012]
#  [514.299988]
#  [517.099976]]

# %%
# Plot the results
import matplotlib.pyplot as plt
plt.plot(train_Y.flatten(), label='Actual')
plt.plot(train_predict.flatten(), label='Predicted')
plt.legend()
plt.show()

plt.plot(test_Y.flatten(), label='Actual')
plt.plot(test_predict.flatten(), label='Predicted')
plt.legend()
plt.show()

# %%
model.save('combmodel.h5')

# %%
# Load the B data for testing
df = pd.read_csv('B.csv')
data = df.reset_index()['Close']

# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
data1 = scaler.fit_transform(np.array(data).reshape(-1, 1))
data = []

for i in data1:
    if ((np.isnan(i)) != True):
        data.append(i)
data=np.array(data).reshape(-1,1)
# data = np.array(data).reshape(-1,1)
# print((data))
# Split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data = data[:train_size, :]
test_data = data[train_size:, :]

print(data)
print(train_data)
# Out:
# [[0.07840884]
#  [0.07840884]
#  [0.07843621]
#  ...
#  [0.94342309]
#  [0.94730792]
#  [0.94615891]]
# [[0.07840884]
#  [0.07840884]
#  [0.07843621]
#  ...
#  [0.75268113]
#  [0.75339239]
#  [0.74518491]]

# %%
def prepare_data(data, look_back=1):
    X, Y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back)])
        Y.append(data[i+look_back])
    return np.array(X), np.array(Y)

look_back = 100
train_X, train_Y = prepare_data(train_data, look_back)
test_X, test_Y = prepare_data(test_data, look_back)

train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

# %%
# Evaluate the model
train_score = model.evaluate(train_X, train_Y, verbose=0)
test_score = model.evaluate(test_X, test_Y, verbose=0)
print('Train Score: {:.2f} MSE ({:.2f} RMSE)'.format(train_score, np.sqrt(train_score)))
print('Test Score: {:.2f} MSE ({:.2f} RMSE)'.format(test_score, np.sqrt(test_score)))

# Make predictions
train_predict = model.predict(train_X)
test_predict = model.predict(test_X)
# scaler.scale_
# Inverse the scaling
scale_factor = 1/scaler.scale_
train_predict = scaler.inverse_transform(train_predict)
# train_predict1=train_predict1*scale_factor
train_Y = scaler.inverse_transform(train_Y)
# train_Y=train_Y*scale_factor
test_predict = scaler.inverse_transform(test_predict)
# test_predict1 = test_predict1*scale_factor
test_Y = scaler.inverse_transform(test_Y)
# test_Y = test_Y*scale_factor

print(train_predict)
print(train_Y)
# Out:
# Train Score: 0.00 MSE (0.01 RMSE)
# Test Score: 0.00 MSE (0.02 RMSE)
# 79/79 [==============================] - 3s 40ms/step
# 18/18 [==============================] - 1s 40ms/step
# [[ 11.850275]
#  [ 12.13931 ]
#  [ 12.220837]
#  ...
#  [140.30074 ]
#  [139.76614 ]
#  [139.89835 ]]
# [[ 13.005   ]
#  [ 12.995   ]
#  [ 13.23    ]
#  ...
#  [139.630005]
#  [139.759995]
#  [138.259995]]

# %%
# Plot the results
import matplotlib.pyplot as plt
plt.plot(train_Y.flatten(), label='Actual')
plt.plot(train_predict.flatten(), label='Predicted')
plt.legend()
plt.show()

plt.plot(test_Y.flatten(), label='Actual')
plt.plot(test_predict.flatten(), label='Predicted')
plt.legend()
plt.show()

# %%
# Load the data for J training and testing
df = pd.read_csv('J.csv')
data = df.reset_index()['Close']

# Preprocess the data
scaler = MinMaxScaler(feature_range=(0, 1))
data1 = scaler.fit_transform(np.array(data).reshape(-1, 1))
data = []

for i in data1:
    if ((np.isnan(i)) != True):
        data.append(i)
data=np.array(data).reshape(-1,1)
# data = np.array(data).reshape(-1,1)
# print((data))
# Split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data = data[:train_size, :]
test_data = data[train_size:, :]

print(data)
print(train_data)
# Out:
# [[0.0313568 ]
#  [0.03187823]
#  [0.03155826]
#  ...
#  [0.8661222 ]
#  [0.8661222 ]
#  [0.86113534]]
# [[0.0313568 ]
#  [0.03187823]
#  [0.03155826]
#  ...
#  [0.6934045 ]
#  [0.69561027]
#  [0.69225374]]

# %%
# Prepare the data for training
def prepare_data(data, look_back=1):
    X, Y = [], []
    for i in range(len(data)-look_back):
        X.append(data[i:(i+look_back)])
        Y.append(data[i+look_back])
    return np.array(X), np.array(Y)

look_back = 100
train_X, train_Y = prepare_data(train_data, look_back)
test_X, test_Y = prepare_data(test_data, look_back)

train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1))
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

# %%
# Train the modeldwqefqqqqqqq
model.fit(train_X, train_Y, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 9s 210ms/step - loss: 1.5557e-04
# Epoch 2/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.8210e-04
# Epoch 3/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.3533e-04
# Epoch 4/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.5124e-04
# Epoch 5/100
# 42/42 [==============================] - 10s 242ms/step - loss: 1.1457e-04
# Epoch 6/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.2399e-04
# Epoch 7/100
# 42/42 [==============================] - 11s 254ms/step - loss: 1.0748e-04
# Epoch 8/100
# 42/42 [==============================] - 11s 250ms/step - loss: 1.0561e-04
# Epoch 9/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.1814e-04
# Epoch 10/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.0719e-04
# Epoch 11/100
# 42/42 [==============================] - 10s 241ms/step - loss: 1.2601e-04
# Epoch 12/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.3201e-04
# Epoch 13/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.1670e-04
# Epoch 14/100
# 42/42 [==============================] - 10s 240ms/step - loss: 1.1100e-04
# Epoch 15/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.1105e-04
# Epoch 16/100
# 42/42 [==============================] - 10s 243ms/step - loss: 1.2286e-04
# Epoch 17/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.2405e-04
# Epoch 18/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0988e-04
# Epoch 19/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.0758e-04
# Epoch 20/100
# 42/42 [==============================] - 10s 243ms/step - loss: 1.0757e-04
# Epoch 21/100
# 42/42 [==============================] - 10s 241ms/step - loss: 1.0766e-04
# Epoch 22/100
# 42/42 [==============================] - 10s 239ms/step - loss: 1.3266e-04
# Epoch 23/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.0628e-04
# Epoch 24/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0249e-04
# Epoch 25/100
# 42/42 [==============================] - 11s 262ms/step - loss: 1.0783e-04
# Epoch 26/100
# 42/42 [==============================] - 11s 251ms/step - loss: 1.1007e-04
# Epoch 27/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0574e-04
# Epoch 28/100
# 42/42 [==============================] - 10s 242ms/step - loss: 1.1372e-04
# Epoch 29/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.0522e-04
# Epoch 30/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.0430e-04
# Epoch 31/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0721e-04
# Epoch 32/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.0460e-04
# Epoch 33/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.0684e-04
# Epoch 34/100
# 42/42 [==============================] - 10s 241ms/step - loss: 1.1035e-04
# Epoch 35/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0359e-04
# Epoch 36/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.1979e-04
# Epoch 37/100
# 42/42 [==============================] - 10s 250ms/step - loss: 1.0527e-04
# Epoch 38/100
# 42/42 [==============================] - 11s 255ms/step - loss: 1.0110e-04
# Epoch 39/100
# 42/42 [==============================] - 11s 268ms/step - loss: 1.0923e-04
# Epoch 40/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0798e-04
# Epoch 41/100
# 42/42 [==============================] - 11s 251ms/step - loss: 1.0857e-04
# Epoch 42/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.1777e-04
# Epoch 43/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.3212e-04
# Epoch 44/100
# 42/42 [==============================] - 10s 240ms/step - loss: 1.1087e-04
# Epoch 45/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.1209e-04
# Epoch 46/100
# 42/42 [==============================] - 11s 255ms/step - loss: 1.1427e-04
# Epoch 47/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.1632e-04
# Epoch 48/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0814e-04
# Epoch 49/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0068e-04
# Epoch 50/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.0684e-04
# Epoch 51/100
# 42/42 [==============================] - 10s 243ms/step - loss: 1.0694e-04
# Epoch 52/100
# 42/42 [==============================] - 10s 243ms/step - loss: 1.0100e-04
# Epoch 53/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.0066e-04
# Epoch 54/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0401e-04
# Epoch 55/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.0784e-04
# Epoch 56/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.1426e-04
# Epoch 57/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.0170e-04
# Epoch 58/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.1621e-04
# Epoch 59/100
# 42/42 [==============================] - 11s 252ms/step - loss: 1.2988e-04
# Epoch 60/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.1188e-04
# Epoch 61/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.0477e-04
# Epoch 62/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0721e-04
# Epoch 63/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.1218e-04
# Epoch 64/100
# 42/42 [==============================] - 10s 249ms/step - loss: 1.0079e-04
# Epoch 65/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.1272e-04
# Epoch 66/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.1208e-04
# Epoch 67/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.0956e-04
# Epoch 68/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.1288e-04
# Epoch 69/100
# 42/42 [==============================] - 10s 251ms/step - loss: 1.0334e-04
# Epoch 70/100
# 42/42 [==============================] - 10s 250ms/step - loss: 1.1983e-04
# Epoch 71/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.1474e-04
# Epoch 72/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.1129e-04
# Epoch 73/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.1192e-04
# Epoch 74/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.2024e-04
# Epoch 75/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.0599e-04
# Epoch 76/100
# 42/42 [==============================] - 10s 249ms/step - loss: 9.8184e-05
# Epoch 77/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.1159e-04
# Epoch 78/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0600e-04
# Epoch 79/100
# 42/42 [==============================] - 10s 248ms/step - loss: 1.0373e-04
# Epoch 80/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.0480e-04
# Epoch 81/100
# 42/42 [==============================] - 11s 251ms/step - loss: 1.1122e-04
# Epoch 82/100
# 42/42 [==============================] - 11s 251ms/step - loss: 1.3692e-04
# Epoch 83/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.2766e-04
# Epoch 84/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0975e-04
# Epoch 85/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.0236e-04
# Epoch 86/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.0955e-04
# Epoch 87/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.2066e-04
# Epoch 88/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.0223e-04
# Epoch 89/100
# 42/42 [==============================] - 10s 249ms/step - loss: 1.0595e-04
# Epoch 90/100
# 42/42 [==============================] - 11s 253ms/step - loss: 1.0287e-04
# Epoch 91/100
# 42/42 [==============================] - 11s 251ms/step - loss: 1.1079e-04
# Epoch 92/100
# 42/42 [==============================] - 11s 252ms/step - loss: 1.1036e-04
# Epoch 93/100
# 42/42 [==============================] - 10s 245ms/step - loss: 1.0187e-04
# Epoch 94/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0965e-04
# Epoch 95/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.0390e-04
# Epoch 96/100
# 42/42 [==============================] - 10s 244ms/step - loss: 1.0621e-04
# Epoch 97/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0209e-04
# Epoch 98/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.1753e-04
# Epoch 99/100
# 42/42 [==============================] - 10s 246ms/step - loss: 1.0624e-04
# Epoch 100/100
# 42/42 [==============================] - 10s 247ms/step - loss: 1.1936e-04

# %%
# Evaluate the model
train_score = model.evaluate(train_X, train_Y, verbose=0)
test_score = model.evaluate(test_X, test_Y, verbose=0)
print('Train Score: {:.2f} MSE ({:.2f} RMSE)'.format(train_score, np.sqrt(train_score)))
print('Test Score: {:.2f} MSE ({:.2f} RMSE)'.format(test_score, np.sqrt(test_score)))

# Make predictions
train_predict = model.predict(train_X)
test_predict = model.predict(test_X)
# scaler.scale_
# Inverse the scaling
scale_factor = 1/scaler.scale_
train_predict = scaler.inverse_transform(train_predict)
# train_predict1=train_predict1*scale_factor
train_Y = scaler.inverse_transform(train_Y)
# train_Y=train_Y*scale_factor
test_predict = scaler.inverse_transform(test_predict)
# test_predict1 = test_predict1*scale_factor
test_Y = scaler.inverse_transform(test_Y)
# test_Y = test_Y*scale_factor

print(train_predict)
print(train_Y)
# Out:
# Train Score: 0.00 MSE (0.01 RMSE)
# Test Score: 0.00 MSE (0.01 RMSE)
# 84/84 [==============================] - 4s 48ms/step
# 19/19 [==============================] - 1s 47ms/step
# [[ 38.059082]
#  [ 38.38903 ]
#  [ 38.62052 ]
#  ...
#  [385.5627  ]
#  [391.04556 ]
#  [391.88702 ]]
# [[ 41.34708 ]
#  [ 41.433578]
#  [ 41.680721]
#  ...
#  [389.299988]
#  [390.450012]
#  [388.700012]]

# %%
# Plot the results
import matplotlib.pyplot as plt
plt.plot(train_Y.flatten(), label='Actual')
plt.plot(train_predict.flatten(), label='Predicted')
plt.legend()
plt.show()

plt.plot(test_Y.flatten(), label='Actual')
plt.plot(test_predict.flatten(), label='Predicted')
plt.legend()
plt.show()

# %%
model.save('combmodel.h5')
